# %% [markdown]
# <a href="https://colab.research.google.com/github/EazysPeazys/MinProAVD/blob/main/MinProAVD_Nabil_Daffa_Athalasyah_2409116090.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MINI PROJECT 1

# %% [markdown]
# **BUSINESS UNDERSTANDING**

# %% [markdown]
# Business Objective

# %% [markdown]
# Analisis ini bertujuan untuk memahami berbagai faktor yang memengaruhi peringkat universitas dalam QS World University Rankings 2024. Dengan analisis ini, diharapkan dapat memberikan wawasan yang bermanfaat bagi calon mahasiswa dalam memilih universitas berdasarkan kriteria tertentu, serta membantu institusi pendidikan dalam meningkatkan peringkat mereka. Selain itu, analisis ini juga bertujuan untuk mengidentifikasi tren global dalam pendidikan tinggi dengan mempertimbangkan aspek akademik, penelitian, dan tingkat internasionalisasi.

# %% [markdown]
# Assess Situation

# %% [markdown]
# Analisis ini melibatkan berbagai pemangku kepentingan, termasuk universitas dan akademisi, calon mahasiswa beserta orang tua, perusahaan yang mencari lulusan berkualitas, serta pemerintah dan pembuat kebijakan pendidikan. Sumber data utama yang digunakan berasal dari dataset QS World University Rankings, dengan berbagai faktor penentu seperti reputasi akademik, jumlah sitasi, proporsi fakultas internasional, serta aspek keberlanjutan. Namun, terdapat beberapa kendala dalam proses analisis ini, seperti data yang tidak lengkap pada beberapa kolom, termasuk Research, International Faculty, dan Sustainability Score. Oleh karena itu, diperlukan proses pembersihan dan pengolahan data agar analisis yang dilakukan lebih akurat. Selain itu, karena sebagian besar data berbentuk string, diperlukan konversi ke format numerik untuk memungkinkan analisis kuantitatif yang lebih mendalam.

# %% [markdown]
# Data Mining Goals

# %% [markdown]
# Tujuan utama dari analisis data mining ini adalah untuk mengidentifikasi universitas terbaik berdasarkan faktor-faktor utama yang memengaruhi peringkat. Selain itu, analisis ini juga bertujuan untuk mengevaluasi pola perubahan peringkat universitas dari tahun ke tahun, serta memahami hubungan antara faktor-faktor yang menentukan peringkat tersebut. Lebih jauh, analisis ini berusaha mengidentifikasi negara dengan performa terbaik dalam sektor pendidikan tinggi serta menyoroti universitas yang unggul dalam hal keberlanjutan dan penelitian internasional.

# %% [markdown]
# Project Plan

# %% [markdown]
# Proses analisis ini akan dilakukan melalui beberapa tahapan utama, yaitu:
#
# 1. Persiapan Data
#
# - Melakukan pembersihan dataset.
# - Mengonversi format data ke bentuk numerik.
# - Menangani data yang tidak lengkap.
#
# 2. Eksplorasi Data
#
# - Menganalisis distribusi universitas berdasarkan negara.
# - Mengidentifikasi universitas terbaik berdasarkan berbagai faktor.
# - Mengamati tren perubahan peringkat universitas dari tahun ke tahun.
#
# 3. Analisis Korelasi
#
# - Menghitung korelasi antara faktor-faktor utama yang berkontribusi terhadap peringkat.
# - Mengidentifikasi faktor yang paling berpengaruh.
#
# 4. Visualisasi Data
#
# - Menyajikan grafik distribusi universitas berdasarkan negara.
# - Memvisualisasikan hubungan antara faktor-faktor peringkat.
#
# 5. Kesimpulan dan Rekomendasi
#
# - Merangkum temuan utama dari hasil analisis.
# - Memberikan rekomendasi bagi universitas, calon mahasiswa, dan pembuat kebijakan pendidikan.

# %% [markdown]
# # MINI PROJECT 2

# %% [markdown]
# DATA UNDERSTANDING

# %% [markdown]
# TEMA "QS World University Rankings"
#
# SUMBER DATA KAGGLE: "https://www.kaggle.com/datasets/joebeachcapital/qs-world-university-rankings-2024/data%22"
#
# Terdapat sebanyak 1498 Baris dan 29 Kolom.

# %%
import pandas as pd

file = "/content/2024 QS World University Rankings 1.1 (For qs.com) (1).csv"

df = pd.read_csv(file)
df
# Out:
#          2024 RANK      2023 RANK  \
# 0     rank display  rank display2
# 1                1              1
# 2                2              2
# 3                3              4
# 4                4              5
# ...            ...            ...
# 1493         1401+          1401+
# 1494         1401+            NaN
# 1495         1401+      1201-1400
# 1496         1401+      1201-1400
# 1497         1401+            NaN
#
#                                   Institution Name   Country Code  \
# 0                                      institution  location code
# 1     Massachusetts Institute of Technology (MIT)              US
# 2                          University of Cambridge             UK
# 3                             University of Oxford             UK
# 4                               Harvard University             US
# ...                                            ...            ...
# 1493                          University of Oradea             RO
# 1494                       University of Stavanger             NO
# 1495      University Politehnica of Timisoara, UPT             RO
# 1496                 Western Washington University             US
# 1497                 Zürcher Hochschule Winterthur             CH
#
#              Country  SIZE  FOCUS      RES.       AGE  STATUS  ...  \
# 0           location  size  focus  research  age band  status  ...
# 1      United States     M     CO        VH         5       B  ...
# 2     United Kingdom     L     FC        VH         5       A  ...
# 3     United Kingdom     L     FC        VH         5       A  ...
# 4      United States     L     FC        VH         5       B  ...
# ...              ...   ...    ...       ...       ...     ...  ...
# 1493         Romania     L     FC        MD         4       A  ...
# 1494          Norway   NaN     CO       NaN         2     NaN  ...
# 1495         Romania     M     FO        VH         5       A  ...
# 1496   United States     L     CO        HI         5     NaN  ...
# 1497     Switzerland   NaN     CO       NaN       NaN     NaN  ...
#
#      International Faculty Rank International Students Score  \
# 0                      ifr rank                    isr score
# 1                            56                         88.2
# 2                            64                         95.8
# 3                           110                         98.2
# 4                           210                         66.8
# ...                         ...                          ...
# 1493                       701+                          7.0
# 1494                        NaN                          NaN
# 1495                       701+                          2.9
# 1496                        676                          1.4
# 1497                        NaN                          NaN
#
#      International Students Rank International Research Network Score  \
# 0                       isr rank                            irn score
# 1                            128                                 94.3
# 2                             85                                 99.9
# 3                             60                                100.0
# 4                            223                                100.0
# ...                          ...                                  ...
# 1493                        701+                                  1.8
# 1494                         NaN                                 26.3
# 1495                        701+                                  1.3
# 1496                        701+                                  1.0
# 1497                         NaN                                  1.7
#
#      International Research Network Rank Employment Outcomes Score  \
# 0                               irn rank                 ger score
# 1                                     58                       100
# 2                                      7                       100
# 3                                      1                       100
# 4                                      5                       100
# ...                                  ...                       ...
# 1493                                701+                       5.9
# 1494                                 489                       NaN
# 1495                                701+                       8.5
# 1496                                701+                       7.3
# 1497                                701+                       NaN
#
#      Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# 0                    ger rank            SUS SCORE            SUS RANK
# 1                           4                 95.2                  51
# 2                           6                 97.3                 33=
# 3                           3                 97.8                 26=
# 4                           1                 96.7                  39
# ...                       ...                  ...                 ...
# 1493                     701+                  2.2                701+
# 1494                      NaN                  NaN                 NaN
# 1495                     701+                    1                701+
# 1496                     701+                  NaN                 NaN
# 1497                      NaN                  NaN                 NaN
#
#       Overall SCORE
# 0     Overall Score
# 1             100.0
# 2              99.2
# 3              98.9
# 4              98.3
# ...             ...
# 1493              -
# 1494              -
# 1495              -
# 1496              -
# 1497              -
#
# [1498 rows x 29 columns]

# %% [markdown]
# Melihat Jumlah Baris

# %%
df.shape
# Out:
# (1498, 29)

# %% [markdown]
# Cek Tipe Data Setiap Kolom

# %%
df.dtypes
# Out:
# 2024 RANK                               object
# 2023 RANK                               object
# Institution Name                        object
# Country Code                            object
# Country                                 object
# SIZE                                    object
# FOCUS                                   object
# RES.                                    object
# AGE                                     object
# STATUS                                  object
# Academic Reputation Score               object
# Academic Reputation Rank                object
# Employer Reputation Score               object
# Employer Reputation Rank                object
# Faculty Student Score                   object
# Faculty Student Rank                    object
# Citations per Faculty Score             object
# Citations per Faculty Rank              object
# International Faculty Score             object
# International Faculty Rank              object
# International Students Score            object
# International Students Rank             object
# International Research Network Score    object
# International Research Network Rank     object
# Employment Outcomes Score               object
# Employment Outcomes Rank                object
# Sustainability Score                    object
# Sustainability Rank                     object
# Overall SCORE                           object
# dtype: object

# %% [markdown]
# STATISTIK DESKRIPTIF

# %%
# Statistik Deskriptif
df.describe()
# Out:
#         2024 RANK 2023 RANK Institution Name Country Code        Country  \
# count        1498      1416             1498         1498           1498
# unique        380       334             1498          105            105
# top     1201-1400  801-1000      institution           US  United States
# freq          206       204                1          199            199
#
#         SIZE FOCUS  RES.   AGE STATUS  ... International Faculty Rank  \
# count   1475  1497  1411  1472   1456  ...                       1372
# unique     5     5     5     6      4  ...                        684
# top        L    FC    VH     5      A  ...                       701+
# freq     688   595   922   543   1157  ...                        684
#
#        International Students Score International Students Rank  \
# count                          1418                        1418
# unique                          524                         688
# top                             1.1                        701+
# freq                             36                         727
#
#        International Research Network Score  \
# count                                  1494
# unique                                  555
# top                                     1.0
# freq                                    281
#
#        International Research Network Rank Employment Outcomes Score  \
# count                                 1494                      1474
# unique                                 700                       450
# top                                   701+                       7.9
# freq                                   790                        20
#
#        Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# count                      1474                 1398                1398
# unique                      693                  400                 344
# top                        701+                    1                701+
# freq                        782                  174                 697
#
#        Overall SCORE
# count           1498
# unique           351
# top                -
# freq             895
#
# [4 rows x 29 columns]

# %% [markdown]
# DATA PREPARATION

# %% [markdown]
# TEMA "QS World University Rankings"
#
# SUMBER DATA KAGGLE: "https://www.kaggle.com/datasets/joebeachcapital/qs-world-university-rankings-2024/data%22"
#
# Terdapat sebanyak 1498 Baris dan 29 Kolom.

# %%
import pandas as pd

file = "/content/2024 QS World University Rankings 1.1 (For qs.com).csv"

df = pd.read_csv(file)
df
# Out:
#          2024 RANK      2023 RANK  \
# 0     rank display  rank display2
# 1                1              1
# 2                2              2
# 3                3              4
# 4                4              5
# ...            ...            ...
# 1493         1401+          1401+
# 1494         1401+            NaN
# 1495         1401+      1201-1400
# 1496         1401+      1201-1400
# 1497         1401+            NaN
#
#                                   Institution Name   Country Code  \
# 0                                      institution  location code
# 1     Massachusetts Institute of Technology (MIT)              US
# 2                          University of Cambridge             UK
# 3                             University of Oxford             UK
# 4                               Harvard University             US
# ...                                            ...            ...
# 1493                          University of Oradea             RO
# 1494                       University of Stavanger             NO
# 1495      University Politehnica of Timisoara, UPT             RO
# 1496                 Western Washington University             US
# 1497                 Zürcher Hochschule Winterthur             CH
#
#              Country  SIZE  FOCUS      RES.       AGE  STATUS  ...  \
# 0           location  size  focus  research  age band  status  ...
# 1      United States     M     CO        VH         5       B  ...
# 2     United Kingdom     L     FC        VH         5       A  ...
# 3     United Kingdom     L     FC        VH         5       A  ...
# 4      United States     L     FC        VH         5       B  ...
# ...              ...   ...    ...       ...       ...     ...  ...
# 1493         Romania     L     FC        MD         4       A  ...
# 1494          Norway   NaN     CO       NaN         2     NaN  ...
# 1495         Romania     M     FO        VH         5       A  ...
# 1496   United States     L     CO        HI         5     NaN  ...
# 1497     Switzerland   NaN     CO       NaN       NaN     NaN  ...
#
#      International Faculty Rank International Students Score  \
# 0                      ifr rank                    isr score
# 1                            56                         88.2
# 2                            64                         95.8
# 3                           110                         98.2
# 4                           210                         66.8
# ...                         ...                          ...
# 1493                       701+                          7.0
# 1494                        NaN                          NaN
# 1495                       701+                          2.9
# 1496                        676                          1.4
# 1497                        NaN                          NaN
#
#      International Students Rank International Research Network Score  \
# 0                       isr rank                            irn score
# 1                            128                                 94.3
# 2                             85                                 99.9
# 3                             60                                100.0
# 4                            223                                100.0
# ...                          ...                                  ...
# 1493                        701+                                  1.8
# 1494                         NaN                                 26.3
# 1495                        701+                                  1.3
# 1496                        701+                                  1.0
# 1497                         NaN                                  1.7
#
#      International Research Network Rank Employment Outcomes Score  \
# 0                               irn rank                 ger score
# 1                                     58                       100
# 2                                      7                       100
# 3                                      1                       100
# 4                                      5                       100
# ...                                  ...                       ...
# 1493                                701+                       5.9
# 1494                                 489                       NaN
# 1495                                701+                       8.5
# 1496                                701+                       7.3
# 1497                                701+                       NaN
#
#      Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# 0                    ger rank            SUS SCORE            SUS RANK
# 1                           4                 95.2                  51
# 2                           6                 97.3                 33=
# 3                           3                 97.8                 26=
# 4                           1                 96.7                  39
# ...                       ...                  ...                 ...
# 1493                     701+                  2.2                701+
# 1494                      NaN                  NaN                 NaN
# 1495                     701+                    1                701+
# 1496                     701+                  NaN                 NaN
# 1497                      NaN                  NaN                 NaN
#
#       Overall SCORE
# 0     Overall Score
# 1             100.0
# 2              99.2
# 3              98.9
# 4              98.3
# ...             ...
# 1493              -
# 1494              -
# 1495              -
# 1496              -
# 1497              -
#
# [1498 rows x 29 columns]

# %% [markdown]
# MISSING VALUES

# %%
# Missing Values
print((df.isna().sum() / len(df)) * 100)
# Out:
# 2024 RANK                               0.000000
# 2023 RANK                               5.473965
# Institution Name                        0.000000
# Country Code                            0.000000
# Country                                 0.000000
# SIZE                                    1.535381
# FOCUS                                   0.066756
# RES.                                    5.807744
# AGE                                     1.735648
# STATUS                                  2.803738
# Academic Reputation Score               0.000000
# Academic Reputation Rank                0.000000
# Employer Reputation Score               0.066756
# Employer Reputation Rank                0.066756
# Faculty Student Score                   1.602136
# Faculty Student Rank                    1.602136
# Citations per Faculty Score             1.602136
# Citations per Faculty Rank              1.602136
# International Faculty Score             8.411215
# International Faculty Rank              8.411215
# International Students Score            5.340454
# International Students Rank             5.340454
# International Research Network Score    0.267023
# International Research Network Rank     0.267023
# Employment Outcomes Score               1.602136
# Employment Outcomes Rank                1.602136
# Sustainability Score                    6.675567
# Sustainability Rank                     6.675567
# Overall SCORE                           0.000000
# dtype: float64

# %% [markdown]
# DUPLIKAT

# %%
# Duplikat
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [2024 RANK, 2023 RANK, Institution Name, Country Code, Country, SIZE, FOCUS, RES., AGE, STATUS, Academic Reputation Score, Academic Reputation Rank, Employer Reputation Score, Employer Reputation Rank, Faculty Student Score, Faculty Student Rank, Citations per Faculty Score, Citations per Faculty Rank, International Faculty Score, International Faculty Rank, International Students Score, International Students Rank, International Research Network Score, International Research Network Rank, Employment Outcomes Score, Employment Outcomes Rank, Sustainability Score, Sustainability Rank, Overall SCORE]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# Data Reduction

# %%
df.columns
# Out:
# Index(['2024 RANK', '2023 RANK', 'Institution Name', 'Country Code', 'Country',
#        'SIZE', 'FOCUS', 'RES.', 'AGE', 'STATUS', 'Academic Reputation Score',
#        'Academic Reputation Rank', 'Employer Reputation Score',
#        'Employer Reputation Rank', 'Faculty Student Score',
#        'Faculty Student Rank', 'Citations per Faculty Score',
#        'Citations per Faculty Rank', 'International Faculty Score',
#        'International Faculty Rank', 'International Students Score',
#        'International Students Rank', 'International Research Network Score',
#        'International Research Network Rank', 'Employment Outcomes Score',
#        'Employment Outcomes Rank', 'Sustainability Score',
#        'Sustainability Rank', 'Overall SCORE'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
import pandas as pd

# Membaca file CSV
file = "/content/2024 QS World University Rankings 1.1 (For qs.com).csv"
df = pd.read_csv(file)

# Membersihkan nama kolom dari spasi
df.columns = df.columns.str.strip()

# Mengecek apakah kolom yang ingin dihapus ada dalam DataFrame
columns_to_drop = ['2024 Rank', 'Overall Score']
existing_columns = [col for col in columns_to_drop if col in df.columns]

if existing_columns:
    df.drop(columns=existing_columns, axis=1, inplace=True)

# Menampilkan nama kolom setelah perubahan
print(df.columns)
# Out:
# Index(['2024 RANK', '2023 RANK', 'Institution Name', 'Country Code', 'Country',
#        'SIZE', 'FOCUS', 'RES.', 'AGE', 'STATUS', 'Academic Reputation Score',
#        'Academic Reputation Rank', 'Employer Reputation Score',
#        'Employer Reputation Rank', 'Faculty Student Score',
#        'Faculty Student Rank', 'Citations per Faculty Score',
#        'Citations per Faculty Rank', 'International Faculty Score',
#        'International Faculty Rank', 'International Students Score',
#        'International Students Rank', 'International Research Network Score',
#        'International Research Network Rank', 'Employment Outcomes Score',
#        'Employment Outcomes Rank', 'Sustainability Score',
#        'Sustainability Rank', 'Overall SCORE'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['2024 RANK', '2023 RANK', 'Institution Name', 'Country Code', 'Country',
#        'SIZE', 'FOCUS', 'RES.', 'AGE', 'STATUS', 'Academic Reputation Score',
#        'Academic Reputation Rank', 'Employer Reputation Score',
#        'Employer Reputation Rank', 'Faculty Student Score',
#        'Faculty Student Rank', 'Citations per Faculty Score',
#        'Citations per Faculty Rank', 'International Faculty Score',
#        'International Faculty Rank', 'International Students Score',
#        'International Students Rank', 'International Research Network Score',
#        'International Research Network Rank', 'Employment Outcomes Score',
#        'Employment Outcomes Rank', 'Sustainability Score',
#        'Sustainability Rank', 'Overall SCORE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 2024 RANK                               object
# 2023 RANK                               object
# Institution Name                        object
# Country Code                            object
# Country                                 object
# SIZE                                    object
# FOCUS                                   object
# RES.                                    object
# AGE                                     object
# STATUS                                  object
# Academic Reputation Score               object
# Academic Reputation Rank                object
# Employer Reputation Score               object
# Employer Reputation Rank                object
# Faculty Student Score                   object
# Faculty Student Rank                    object
# Citations per Faculty Score             object
# Citations per Faculty Rank              object
# International Faculty Score             object
# International Faculty Rank              object
# International Students Score            object
# International Students Rank             object
# International Research Network Score    object
# International Research Network Rank     object
# Employment Outcomes Score               object
# Employment Outcomes Rank                object
# Sustainability Score                    object
# Sustainability Rank                     object
# Overall SCORE                           object
# dtype: object

# %% [markdown]
# MENGUBAH TIPE DATA

# %%
columns_to_convert = [
    'Academic Reputation', 'Employer Reputation', 'Faculty Student',
    'Citations per Faculty', 'International Faculty',
    'International Students', 'Sustainability'
]

for col in columns_to_convert:
    if col in df.columns:
        # Mengganti NaN dengan 0 dan memastikan format string
        df[col] = df[col].astype(str).fillna('0')

        # Menghapus karakter yang bukan angka, titik, atau minus
        df[col] = df[col].str.replace(r'[^\d.-]', '', regex=True)

        # Mengonversi ke tipe float dengan error handling
        df[col] = pd.to_numeric(df[col], errors='coerce')
    else:
        print(f"Warning: Column '{col}' not found in DataFrame. Skipping...")

# Menampilkan tipe data setelah konversi
print(df.dtypes)
# Out:
# Warning: Column 'Academic Reputation' not found in DataFrame. Skipping...
# Warning: Column 'Employer Reputation' not found in DataFrame. Skipping...
# Warning: Column 'Faculty Student' not found in DataFrame. Skipping...
# Warning: Column 'Citations per Faculty' not found in DataFrame. Skipping...
# Warning: Column 'International Faculty' not found in DataFrame. Skipping...
# Warning: Column 'International Students' not found in DataFrame. Skipping...
# Warning: Column 'Sustainability' not found in DataFrame. Skipping...
# 2024 RANK                               object
# 2023 RANK                               object
# Institution Name                        object
# Country Code                            object
# Country                                 object
# SIZE                                    object
# FOCUS                                   object
# RES.                                    object
# AGE                                     object
# STATUS                                  object
# Academic Reputation Score               object
# Academic Reputation Rank                object
# Employer Reputation Score               object
# Employer Reputation Rank                object
# Faculty Student Score                   object
# Faculty Student Rank                    object
# Citations per Faculty Score             object
# Citations per Faculty Rank              object
# International Faculty Score             object
# International Faculty Rank              object
# International Students Score            object
# International Students Rank             object
# International Research Network Score    object
# International Research Network Rank     object
# Employment Outcomes Score               object
# Employment Outcomes Rank                object
# Sustainability Score                    object
# Sustainability Rank                     object
# Overall SCORE                           object
# dtype: object

# %%
df.dtypes
# Out:
# 2024 RANK                               object
# 2023 RANK                               object
# Institution Name                        object
# Country Code                            object
# Country                                 object
# SIZE                                    object
# FOCUS                                   object
# RES.                                    object
# AGE                                     object
# STATUS                                  object
# Academic Reputation Score               object
# Academic Reputation Rank                object
# Employer Reputation Score               object
# Employer Reputation Rank                object
# Faculty Student Score                   object
# Faculty Student Rank                    object
# Citations per Faculty Score             object
# Citations per Faculty Rank              object
# International Faculty Score             object
# International Faculty Rank              object
# International Students Score            object
# International Students Rank             object
# International Research Network Score    object
# International Research Network Rank     object
# Employment Outcomes Score               object
# Employment Outcomes Rank                object
# Sustainability Score                    object
# Sustainability Rank                     object
# Overall SCORE                           object
# dtype: object

# %%
import pandas as pd

# Menyimpan hasil analisis outlier
results = []

# Memilih hanya kolom bertipe numerik (float atau integer)
numeric_cols = df.select_dtypes(include=['number']).columns

for col in numeric_cols:
    # Menghitung Q1, Q3, dan IQR
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Menemukan outlier
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers) / len(df)) * 100

    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Membuat DataFrame dari hasil analisis
results_df = pd.DataFrame(results)

# Menetapkan kolom 'Kolom' sebagai index
results_df.set_index('Kolom', inplace=True)

# Menampilkan hasil
display(results_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-7bb26e275fd2> in <cell line: 0>()
#      25
#      26 # Menetapkan kolom 'Kolom' sebagai index
# ---> 27 results_df.set_index('Kolom', inplace=True)
#      28
#      29 # Menampilkan hasil
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Kolom'] are in the columns"

# %% [markdown]
# OUTLIERS

# %%
columns_to_impute = [
    "Academic Reputation", "Employer Reputation", "Faculty Student",
    "Citations per Faculty", "International Faculty",
    "International Students", "Sustainability"
]

for col in columns_to_impute:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Menggunakan .loc[] untuk menghindari SettingWithCopyWarning
        df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    else:
        print(f"Warning: Column '{col}' not found in DataFrame. Skipping...")

# Menampilkan ringkasan data setelah capping
print(df.describe())
# Out:
# Warning: Column 'Academic Reputation' not found in DataFrame. Skipping...
# Warning: Column 'Employer Reputation' not found in DataFrame. Skipping...
# Warning: Column 'Faculty Student' not found in DataFrame. Skipping...
# Warning: Column 'Citations per Faculty' not found in DataFrame. Skipping...
# Warning: Column 'International Faculty' not found in DataFrame. Skipping...
# Warning: Column 'International Students' not found in DataFrame. Skipping...
# Warning: Column 'Sustainability' not found in DataFrame. Skipping...
#         2024 RANK 2023 RANK Institution Name Country Code        Country  \
# count        1498      1416             1498         1498           1498
# unique        380       334             1498          105            105
# top     1201-1400  801-1000      institution           US  United States
# freq          206       204                1          199            199
#
#         SIZE FOCUS  RES.   AGE STATUS  ... International Faculty Rank  \
# count   1475  1497  1411  1472   1456  ...                       1372
# unique     5     5     5     6      4  ...                        684
# top        L    FC    VH     5      A  ...                       701+
# freq     688   595   922   543   1157  ...                        684
#
#        International Students Score International Students Rank  \
# count                          1418                        1418
# unique                          524                         688
# top                             1.1                        701+
# freq                             36                         727
#
#        International Research Network Score  \
# count                                  1494
# unique                                  555
# top                                     1.0
# freq                                    281
#
#        International Research Network Rank Employment Outcomes Score  \
# count                                 1494                      1474
# unique                                 700                       450
# top                                   701+                       7.9
# freq                                   790                        20
#
#        Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# count                      1474                 1398                1398
# unique                      693                  400                 344
# top                        701+                    1                701+
# freq                        782                  174                 697
#
#        Overall SCORE
# count           1498
# unique           351
# top                -
# freq             895
#
# [4 rows x 29 columns]

# %%
results = []

# Pilih hanya kolom numerik (float64 dan int64)
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in numeric_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Identifikasi outlier
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers) / len(df)) * 100

    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Buat DataFrame dari hasil analisis
results_df = pd.DataFrame(results)

# Set kolom sebagai index
results_df.set_index('Kolom', inplace=True)

# Menampilkan hasil
display(results_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-5bb87a436a73> in <cell line: 0>()
#      21
#      22 # Set kolom sebagai index
# ---> 23 results_df.set_index('Kolom', inplace=True)
#      24
#      25 # Menampilkan hasil
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Kolom'] are in the columns"

# %%
df

# %% [markdown]
# CONSTRUCT DATA

# %%
# Menghitung persentase indikator kinerja universitas
df['Faculty Student Ratio (%)'] = (df['Faculty Student'] / df['International Students']) * 100
df['Citations Impact (%)'] = (df['Citations per Faculty'] / df['Academic Reputation']) * 100
df['International Faculty Ratio (%)'] = (df['International Faculty'] / df['Faculty Student']) * 100

# Menampilkan hasil
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Faculty Student'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-9619b76fca43> in <cell line: 0>()
#       1 # Menghitung persentase indikator kinerja universitas
# ----> 2 df['Faculty Student Ratio (%)'] = (df['Faculty Student'] / df['International Students']) * 100
#       3 df['Citations Impact (%)'] = (df['Citations per Faculty'] / df['Academic Reputation']) * 100
#       4 df['International Faculty Ratio (%)'] = (df['International Faculty'] / df['Faculty Student']) * 100
#       5
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Faculty Student'

# %%
df

# %%
import pandas as pd

file = "/content/2024 QS World University Rankings 1.1 (For qs.com).csv"

df = pd.read_csv(file) # Reload the original dataframe to ensure the 'Academic Reputation' column is present.


# ... (Your previous data cleaning and transformation code here) ...

def categorize_reputation(score):
    if score < 50:
        return 'Low Reputation'
    elif 50 <= score <= 75:
        return 'Medium Reputation'
    else:
        return 'High Reputation'

# Kategori berdasarkan Academic Reputation
df['Reputation Category'] = df['Academic Reputation'].apply(categorize_reputation)

# Menampilkan hasil
print(df[['Academic Reputation', 'Reputation Category']].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Academic Reputation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-9b4ad04df243> in <cell line: 0>()
#      17
#      18 # Kategori berdasarkan Academic Reputation
# ---> 19 df['Reputation Category'] = df['Academic Reputation'].apply(categorize_reputation)
#      20
#      21 # Menampilkan hasil
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Academic Reputation'

# %%
df
# Out:
#          2024 RANK      2023 RANK  \
# 0     rank display  rank display2
# 1                1              1
# 2                2              2
# 3                3              4
# 4                4              5
# ...            ...            ...
# 1493         1401+          1401+
# 1494         1401+            NaN
# 1495         1401+      1201-1400
# 1496         1401+      1201-1400
# 1497         1401+            NaN
#
#                                   Institution Name   Country Code  \
# 0                                      institution  location code
# 1     Massachusetts Institute of Technology (MIT)              US
# 2                          University of Cambridge             UK
# 3                             University of Oxford             UK
# 4                               Harvard University             US
# ...                                            ...            ...
# 1493                          University of Oradea             RO
# 1494                       University of Stavanger             NO
# 1495      University Politehnica of Timisoara, UPT             RO
# 1496                 Western Washington University             US
# 1497                 Zürcher Hochschule Winterthur             CH
#
#              Country  SIZE  FOCUS      RES.       AGE  STATUS  ...  \
# 0           location  size  focus  research  age band  status  ...
# 1      United States     M     CO        VH         5       B  ...
# 2     United Kingdom     L     FC        VH         5       A  ...
# 3     United Kingdom     L     FC        VH         5       A  ...
# 4      United States     L     FC        VH         5       B  ...
# ...              ...   ...    ...       ...       ...     ...  ...
# 1493         Romania     L     FC        MD         4       A  ...
# 1494          Norway   NaN     CO       NaN         2     NaN  ...
# 1495         Romania     M     FO        VH         5       A  ...
# 1496   United States     L     CO        HI         5     NaN  ...
# 1497     Switzerland   NaN     CO       NaN       NaN     NaN  ...
#
#      International Faculty Rank International Students Score  \
# 0                      ifr rank                    isr score
# 1                            56                         88.2
# 2                            64                         95.8
# 3                           110                         98.2
# 4                           210                         66.8
# ...                         ...                          ...
# 1493                       701+                          7.0
# 1494                        NaN                          NaN
# 1495                       701+                          2.9
# 1496                        676                          1.4
# 1497                        NaN                          NaN
#
#      International Students Rank International Research Network Score  \
# 0                       isr rank                            irn score
# 1                            128                                 94.3
# 2                             85                                 99.9
# 3                             60                                100.0
# 4                            223                                100.0
# ...                          ...                                  ...
# 1493                        701+                                  1.8
# 1494                         NaN                                 26.3
# 1495                        701+                                  1.3
# 1496                        701+                                  1.0
# 1497                         NaN                                  1.7
#
#      International Research Network Rank Employment Outcomes Score  \
# 0                               irn rank                 ger score
# 1                                     58                       100
# 2                                      7                       100
# 3                                      1                       100
# 4                                      5                       100
# ...                                  ...                       ...
# 1493                                701+                       5.9
# 1494                                 489                       NaN
# 1495                                701+                       8.5
# 1496                                701+                       7.3
# 1497                                701+                       NaN
#
#      Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# 0                    ger rank            SUS SCORE            SUS RANK
# 1                           4                 95.2                  51
# 2                           6                 97.3                 33=
# 3                           3                 97.8                 26=
# 4                           1                 96.7                  39
# ...                       ...                  ...                 ...
# 1493                     701+                  2.2                701+
# 1494                      NaN                  NaN                 NaN
# 1495                     701+                    1                701+
# 1496                     701+                  NaN                 NaN
# 1497                      NaN                  NaN                 NaN
#
#       Overall SCORE
# 0     Overall Score
# 1             100.0
# 2              99.2
# 3              98.9
# 4              98.3
# ...             ...
# 1493              -
# 1494              -
# 1495              -
# 1496              -
# 1497              -
#
# [1498 rows x 29 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (Pastikan file tersedia)
file_path = 'data.csv'  # Ubah path sesuai kebutuhan
try:
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully.")
except Exception as e:
    print(f"Error loading dataset: {e}")

# Menampilkan informasi awal dataset
print(df.info())
print(df.head())

# Mengatasi missing values
df.fillna(method='ffill', inplace=True)

# Menghapus duplikasi jika ada
df.drop_duplicates(inplace=True)

# Mengubah format kolom tanggal jika ada kolom yang berisi tanggal
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Menampilkan deskripsi statistik
print(df.describe())

# Visualisasi distribusi data
plt.figure(figsize=(10, 5))
sns.histplot(df.select_dtypes(include=[np.number]), bins=30, kde=True)
plt.title('Distribusi Data Numerik')
plt.show()

# Visualisasi korelasi
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriks Korelasi')
plt.show()

# Menyimpan data yang sudah dibersihkan
df.to_csv('cleaned_data.csv', index=False)
print("Data cleaned and saved successfully.")
# Out:
# Error loading dataset: [Errno 2] No such file or directory: 'data.csv'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   2024 RANK                             1498 non-null   object
#  1   2023 RANK                             1416 non-null   object
#  2   Institution Name                      1498 non-null   object
#  3   Country Code                          1498 non-null   object
#  4   Country                               1498 non-null   object
#  5   SIZE                                  1475 non-null   object
#  6   FOCUS                                 1497 non-null   object
#  7   RES.                                  1411 non-null   object
#  8   AGE                                   1472 non-null   object
#  9   STATUS                                1456 non-null   object
#  10  Academic Reputation Score             1498 non-null   object
#  11  Academic Reputation Rank              1498 non-null   object
#  12  Employer Reputation Score             1497 non-null   object
#  13  Employer Reputation Rank              1497 non-null   object
#  14  Faculty Student Score                 1474 non-null   object
#  15  Faculty Student Rank                  1474 non-null   object
#  16  Citations per Faculty Score           1474 non-null   object
#  17  Citations per Faculty Rank            1474 non-null   object
#  18  International Faculty Score           1372 non-null   object
#  19  International Faculty Rank            1372 non-null   object
#  20  International Students Score          1418 non-null   object
#  21  International Students Rank           1418 non-null   object
#  22  International Research Network Score  1494 non-null   object
#  23  International Research Network Rank   1494 non-null   object
#  24  Employment Outcomes Score             1474 non-null   object
#  25  Employment Outcomes Rank              1474 non-null   object
#  26  Sustainability Score                  1398 non-null   object
#  27  Sustainability Rank                   1398 non-null   object
#  28  Overall SCORE                         1498 non-null   object
# dtypes: object(29)
# memory usage: 339.5+ KB
# None
#       2024 RANK      2023 RANK                              Institution Name  \
# 0  rank display  rank display2                                   institution
# 1             1              1  Massachusetts Institute of Technology (MIT)
# 2             2              2                       University of Cambridge
# 3             3              4                          University of Oxford
# 4             4              5                            Harvard University
#
#     Country Code         Country  SIZE  FOCUS      RES.       AGE  STATUS  \
# 0  location code        location  size  focus  research  age band  status
# 1             US   United States     M     CO        VH         5       B
# 2             UK  United Kingdom     L     FC        VH         5       A
# 3             UK  United Kingdom     L     FC        VH         5       A
# 4             US   United States     L     FC        VH         5       B
#
#    ... International Faculty Rank International Students Score  \
# 0  ...                   ifr rank                    isr score
# 1  ...                         56                         88.2
# 2  ...                         64                         95.8
# 3  ...                        110                         98.2
# 4  ...                        210                         66.8
#
#   International Students Rank International Research Network Score  \
# 0                    isr rank                            irn score
# 1                         128                                 94.3
# 2                          85                                 99.9
# 3                          60                                100.0
# 4                         223                                100.0
#
#   International Research Network Rank Employment Outcomes Score  \
# 0                            irn rank                 ger score
# 1                                  58                       100
# 2                                   7                       100
# 3                                   1                       100
# 4                                   5                       100
#
#   Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# 0                 ger rank            SUS SCORE            SUS RANK
# 1                        4                 95.2                  51
# 2                        6                 97.3                 33=
# 3                        3                 97.8                 26=
# 4                        1                 96.7                  39
#
#    Overall SCORE
# 0  Overall Score
# 1          100.0
# 2           99.2
# 3           98.9
# 4           98.3
#
# [5 rows x 29 columns]
#         2024 RANK  2023 RANK Institution Name Country Code        Country  \
# count        1498       1498             1498         1498           1498
# unique        380        334             1498          105            105
# top     1201-1400  1201-1400      institution           US  United States
# freq          206        240                1          199            199
#
#         SIZE FOCUS  RES.   AGE STATUS  ... International Faculty Rank  \
# count   1498  1498  1498  1498   1498  ...                       1498
# unique     5     5     5     6      4  ...                        684
# top        L    FC    VH     5      A  ...                       701+
# freq     702   595   961   545   1192  ...                        777
#
#        International Students Score International Students Rank  \
# count                          1498                        1498
# unique                          524                         688
# top                             1.1                        701+
# freq                             45                         789
#
#        International Research Network Score  \
# count                                  1498
# unique                                  555
# top                                     1.0
# freq                                    283
#
#        International Research Network Rank Employment Outcomes Score  \
# count                                 1498                      1498
# unique                                 700                       450
# top                                   701+                       7.8
# freq                                   794                        21
#
#        Employment Outcomes Rank Sustainability Score Sustainability Rank  \
# count                      1498                 1498                1498
# unique                      693                  400                 344
# top                        701+                    1                701+
# freq                        806                  199                 768
#
#        Overall SCORE
# count           1498
# unique           351
# top                -
# freq             895
#
# [4 rows x 29 columns]
# <ipython-input-35-02f902a61d49>:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-02f902a61d49> in <cell line: 0>()
#      31 # Visualisasi distribusi data
#      32 plt.figure(figsize=(10, 5))
# ---> 33 sns.histplot(df.select_dtypes(include=[np.number]), bins=30, kde=True)
#      34 plt.title('Distribusi Data Numerik')
#      35 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     445             kde_kws.setdefault("cut", 0)
#     446             kde_kws["cumulative"] = estimate_kws["cumulative"]
# --> 447             densities = self._compute_univariate_density(
#     448                 self.data_variable,
#     449                 common_norm,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, warn_singular)
#     311             if common_grid:
#     312                 all_observations = self.comp_data.dropna()
# --> 313                 estimator.define_support(all_observations[data_variable])
#     314         else:
#     315             common_norm = False
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     126         """Create the evaluation grid for a given data set."""
#     127         if x2 is None:
# --> 128             support = self._define_support_univariate(x1, weights)
#     129         else:
#     130             support = self._define_support_bivariate(x1, x2, weights)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      98     def _define_support_univariate(self, x, weights):
#      99         """Create a 1D grid of evaluation points."""
# --> 100         kde = self._fit(x, weights)
#     101         bw = np.sqrt(kde.covariance.squeeze())
#     102         grid = self._define_support_grid(
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     141             fit_kws["weights"] = weights
#     142
# --> 143         kde = gaussian_kde(fit_data, **fit_kws)
#     144         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     145
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_kde.py in __init__(self, dataset, bw_method, weights)
#     200         self.dataset = atleast_2d(asarray(dataset))
#     201         if not self.dataset.size > 1:
# --> 202             raise ValueError("`dataset` input should have multiple elements.")
#     203
#     204         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.
