# %% [markdown]
# <a href="https://colab.research.google.com/github/EazysPeazys/MinProAVD/blob/main/CheckPoint%203%20Nabil%20Daffa%20Athalasyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**NAMA: NABIL DAFFA ATHALASYAH NIM: 2409116090 C1**

# %% [markdown]
# ##**CHECKPOINT 1 AVD**

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# **Business Objective**

# %% [markdown]
# Analisis ini bertujuan untuk memahami berbagai faktor yang memengaruhi peringkat universitas dalam QS World University Rankings 2024. Dengan analisis ini, diharapkan dapat memberikan wawasan yang bermanfaat bagi calon mahasiswa dalam memilih universitas berdasarkan kriteria tertentu, serta membantu institusi pendidikan dalam meningkatkan peringkat mereka. Selain itu, analisis ini juga bertujuan untuk mengidentifikasi tren global dalam pendidikan tinggi dengan mempertimbangkan aspek akademik, penelitian, dan tingkat internasionalisasi.

# %% [markdown]
# **Assess Situation**

# %% [markdown]
# Analisis ini melibatkan berbagai pemangku kepentingan, termasuk universitas dan akademisi, calon mahasiswa beserta orang tua, perusahaan yang mencari lulusan berkualitas, serta pemerintah dan pembuat kebijakan pendidikan. Sumber data utama yang digunakan berasal dari dataset QS World University Rankings, dengan berbagai faktor penentu seperti reputasi akademik, jumlah sitasi, proporsi fakultas internasional, serta aspek keberlanjutan. Namun, terdapat beberapa kendala dalam proses analisis ini, seperti data yang tidak lengkap pada beberapa kolom, termasuk Research, International Faculty, dan Sustainability Score. Oleh karena itu, diperlukan proses pembersihan dan pengolahan data agar analisis yang dilakukan lebih akurat. Selain itu, karena sebagian besar data berbentuk string, diperlukan konversi ke format numerik untuk memungkinkan analisis kuantitatif yang lebih mendalam.

# %% [markdown]
# **Data Mining Goals**

# %% [markdown]
# Tujuan utama dari analisis data mining ini adalah untuk mengidentifikasi universitas terbaik berdasarkan faktor-faktor utama yang memengaruhi peringkat. Selain itu, analisis ini juga bertujuan untuk mengevaluasi pola perubahan peringkat universitas dari tahun ke tahun, serta memahami hubungan antara faktor-faktor yang menentukan peringkat tersebut. Lebih jauh, analisis ini berusaha mengidentifikasi negara dengan performa terbaik dalam sektor pendidikan tinggi serta menyoroti universitas yang unggul dalam hal keberlanjutan dan penelitian internasional.

# %% [markdown]
# **Project Plan**

# %% [markdown]
# Proses analisis ini akan dilakukan melalui beberapa tahapan utama, yaitu:
#
# 1. Persiapan Data
#
# - Melakukan pembersihan dataset.
# - Mengonversi format data ke bentuk numerik.
# - Menangani data yang tidak lengkap.
#
# 2. Eksplorasi Data
#
# - Menganalisis distribusi universitas berdasarkan negara.
# - Mengidentifikasi universitas terbaik berdasarkan berbagai faktor.
# - Mengamati tren perubahan peringkat universitas dari tahun ke tahun.
#
# 3. Analisis Korelasi
#
# - Menghitung korelasi antara faktor-faktor utama yang berkontribusi terhadap peringkat.
# - Mengidentifikasi faktor yang paling berpengaruh.
#
# 4. Visualisasi Data
#
# - Menyajikan grafik distribusi universitas berdasarkan negara.
# - Memvisualisasikan hubungan antara faktor-faktor peringkat.
#
# 5. Kesimpulan dan Rekomendasi
#
# - Merangkum temuan utama dari hasil analisis.
# - Memberikan rekomendasi bagi universitas, calon mahasiswa, dan pembuat kebijakan pendidikan.

# %% [markdown]
# ##**CHECKPOINT 2 AVD**

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# TEMA "QS World University Rankings 2024"
#
# SUMBER DATA KAGGLE: "https://www.kaggle.com/datasets/joebeachcapital/qs-world-university-rankings-2024/data%22"
#
# Terdapat sebanyak 1497 Baris dan 30 Kolom.

# %%
import pandas as pd

file = "/content/2024 QS World University Rankings 1.1 (For qs.com) (1) (1) (1).csv"

df = pd.read_csv(file)
df
# Out:
#       2024 RANK                              Institution Name         Country  \
# 0           1.0  Massachusetts Institute of Technology (MIT)    United States
# 1           2.0                       University of Cambridge  United Kingdom
# 2           3.0                          University of Oxford  United Kingdom
# 3           4.0                            Harvard University   United States
# 4           5.0                           Stanford University   United States
# ...         ...                                           ...             ...
# 1492       -1.0                          University of Oradea         Romania
# 1493       -1.0                       University of Stavanger          Norway
# 1494       -1.0      University Politehnica of Timisoara, UPT         Romania
# 1495       -1.0                 Western Washington University   United States
# 1496       -1.0                 Zürcher Hochschule Winterthur     Switzerland
#
# ...

# %% [markdown]
# **Melihat Jumlah Baris**

# %%
df.shape
# Out:
# (1497, 30)

# %% [markdown]
# **Cek Tipe Data Setiap Kolom**

# %%
df.dtypes
# Out:
# 2024 RANK                               float64
# Institution Name                         object
# Country                                  object
# SIZE                                     object
# FOCUS                                    object
# RES.                                     object
# AGE                                       int64
# STATUS                                   object
# Academic Reputation Score               float64
# Academic Reputation Rank                float64
# Employer Reputation Score               float64
# Employer Reputation Rank                float64
# Faculty Student Score                   float64
# Faculty Student Rank                    float64
# Citations per Faculty Score             float64
# Citations per Faculty Rank              float64
# International Faculty Score             float64
# International Faculty Rank              float64
# International Students Score            float64
# International Students Rank             float64
# ...

# %% [markdown]
# **STATISTIK DESKRIPTIF**

# %%
df.describe()
# Out:
#          2024 RANK          AGE  Academic Reputation Score  \
# count  1497.000000  1497.000000                1497.000000
# mean    120.114228     4.014028                  19.490782
# std     183.958336     0.970385                  20.249460
# min      -1.000000     1.000000                   3.800000
# 25%      -1.000000     3.000000                   6.000000
# 50%      -1.000000     4.000000                  10.900000
# 75%     228.000000     5.000000                  23.100000
# max     600.000000     5.000000                  78.300000
#
#        Academic Reputation Rank  Employer Reputation Score  \
# count               1497.000000                1497.000000
# mean                 119.531730                  19.054876
# std                  183.871109                  21.484460
# min                   -1.000000                   2.000000
# 25%                   -1.000000                   4.100000
# 50%                   -1.000000                   9.450000
# ...

# %% [markdown]
# #**DATA PREPARATION**

# %% [markdown]
# TEMA "QS World University Rankings"
#
# SUMBER DATA KAGGLE: "https://www.kaggle.com/datasets/joebeachcapital/qs-world-university-rankings-2024/data%22"
#
# Terdapat sebanyak 1497 Baris dan 30 Kolom.

# %%
import pandas as pd

file = "/content/2024 QS World University Rankings 1.1 (For qs.com) (1) (1) (1).csv"

df = pd.read_csv(file)
df
# Out:
#       2024 RANK                              Institution Name         Country  \
# 0           1.0  Massachusetts Institute of Technology (MIT)    United States
# 1           2.0                       University of Cambridge  United Kingdom
# 2           3.0                          University of Oxford  United Kingdom
# 3           4.0                            Harvard University   United States
# 4           5.0                           Stanford University   United States
# ...         ...                                           ...             ...
# 1492       -1.0                          University of Oradea         Romania
# 1493       -1.0                       University of Stavanger          Norway
# 1494       -1.0      University Politehnica of Timisoara, UPT         Romania
# 1495       -1.0                 Western Washington University   United States
# 1496       -1.0                 Zürcher Hochschule Winterthur     Switzerland
#
# ...

# %% [markdown]
# #**MISSING** **VALUES**

# %% [markdown]
# Pada bagian ini, akan dilakukan Pengecekan pada Missing Values.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# 2024 RANK                               0.0
# Institution Name                        0.0
# Country                                 0.0
# SIZE                                    0.0
# FOCUS                                   0.0
# RES.                                    0.0
# AGE                                     0.0
# STATUS                                  0.0
# Academic Reputation Score               0.0
# Academic Reputation Rank                0.0
# Employer Reputation Score               0.0
# Employer Reputation Rank                0.0
# Faculty Student Score                   0.0
# Faculty Student Rank                    0.0
# Citations per Faculty Score             0.0
# Citations per Faculty Rank              0.0
# International Faculty Score             0.0
# International Faculty Rank              0.0
# International Students Score            0.0
# International Students Rank             0.0
# International Research Network Score    0.0
# ...

# %% [markdown]
# Dapat diketahui tidak ada Missing Value di dalam data tersebut.

# %% [markdown]
# #**DUPLICATE VALUES**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [2024 RANK, Institution Name, Country, SIZE, FOCUS, RES., AGE, STATUS, Academic Reputation Score, Academic Reputation Rank, Employer Reputation Score, Employer Reputation Rank, Faculty Student Score, Faculty Student Rank, Citations per Faculty Score, Citations per Faculty Rank, International Faculty Score, International Faculty Rank, International Students Score, International Students Rank, International Research Network Score, International Research Network Rank, Employment Outcomes Score, Employment Outcomes Rank, Sustainability Score, Sustainability Rank, Overall SCORE, Ranking Change, Average Reputation Score, International Score]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# Dapat diketahui tidak ada Duplicate Values di dalam data tersebut.

# %% [markdown]
# #**DATA REDUCTION**

# %% [markdown]
# Pada bagian ini, Saya akan melakukan Data Reduction (Menyeleksi Kolom) kolom mana yang akan saya gunakan, dan tidak digunakan.

# %%
df.columns
# Out:
# Index(['2024 RANK', 'Institution Name', 'Country', 'SIZE', 'FOCUS', 'RES.',
#        'AGE', 'STATUS', 'Academic Reputation Score',
#        'Academic Reputation Rank', 'Employer Reputation Score',
#        'Employer Reputation Rank', 'Faculty Student Score',
#        'Faculty Student Rank', 'Citations per Faculty Score',
#        'Citations per Faculty Rank', 'International Faculty Score',
#        'International Faculty Rank', 'International Students Score',
#        'International Students Rank', 'International Research Network Score',
#        'International Research Network Rank', 'Employment Outcomes Score',
#        'Employment Outcomes Rank', 'Sustainability Score',
#        'Sustainability Rank', 'Overall SCORE', 'Ranking Change',
#        'Average Reputation Score', 'International Score'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

columns_to_drop = ['SIZE', 'FOCUS', 'RES.', 'AGE', 'STATUS', 'Academic Reputation Score', 'Academic Reputation Rank',
                   'Employer Reputation Score', 'Employer Reputation Rank', 'Faculty Student Score', 'Faculty Student Rank',
                   'Citations per Faculty Score', 'Citations per Faculty Rank', 'International Faculty Score',
                   'International Faculty Rank', 'International Students Score', 'International Students Rank',
                   'International Research Network Score', 'International Research Network Rank', 'Employment Outcomes Score',
                   'Employment Outcomes Rank', 'Sustainability Score', 'Sustainability Rank']

existing_columns = [col for col in columns_to_drop if col in df.columns]

df.drop(columns=existing_columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['2024 RANK', 'Institution Name', 'Country', 'Overall SCORE',
#        'Ranking Change', 'Average Reputation Score', 'International Score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 2024 RANK                   float64
# Institution Name             object
# Country                      object
# Overall SCORE               float64
# Ranking Change              float64
# Average Reputation Score    float64
# International Score         float64
# dtype: object

# %% [markdown]
# **Mengubah Tipe Data**

# %% [markdown]
# Mengubah tipe data dari object ke float64.

# %%
columns_to_convert = ['Institution Name', 'Country']

for col in columns_to_convert:
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace('[^0-9.]', '', regex=True)
    df[col] = df[col].replace('', '0')
    df[col] = pd.to_numeric(df[col], errors='coerce')

print(df.dtypes)
# Out:
# 2024 RANK                   float64
# Institution Name            float64
# Country                       int64
# Overall SCORE               float64
# Ranking Change              float64
# Average Reputation Score    float64
# International Score         float64
# dtype: object

# %%
df.dtypes
# Out:
# 2024 RANK                   float64
# Institution Name            float64
# Country                       int64
# Overall SCORE               float64
# Ranking Change              float64
# Average Reputation Score    float64
# International Score         float64
# dtype: object

# %%
results = []

cols = df.select_dtypes(include=['float64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                     Persentase Outliers
# 2024 RANK                            1.803607
# Institution Name                     0.534402
# Overall SCORE                       40.213761
# Ranking Change                      41.148965
# Average Reputation Score             9.018036
# International Score                  2.204409

# %% [markdown]
# #**OUTLIERS**

# %%
columns_to_convert = ['Institution Name', 'Country']

for col in columns_to_convert:
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace('[^0-9.]', '', regex=True)
    df[col] = df[col].replace('', '0')
    df[col] = pd.to_numeric(df[col], errors='coerce')

print(df.dtypes)

# Ensure 'Overall
# Out:
# 2024 RANK                   float64
# Institution Name            float64
# Country                       int64
# Overall SCORE               float64
# Ranking Change              float64
# Average Reputation Score    float64
# International Score         float64
# dtype: object

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})


results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                     Persentase Outliers
# 2024 RANK                            1.803607
# Institution Name                     0.534402
# Country                              0.000000
# Overall SCORE                       40.213761
# Ranking Change                      41.148965
# Average Reputation Score             9.018036
# International Score                  2.204409

# %%
df
# Out:
#       2024 RANK  Institution Name  Country  Overall SCORE  Ranking Change  \
# 0           1.0               0.0        0          65.50             0.0
# 1           2.0               0.0        0          65.50             0.0
# 2           3.0               0.0        0          65.50             1.0
# 3           4.0               0.0        0          65.50             1.0
# 4           5.0               0.0        0          65.50            -2.0
# ...         ...               ...      ...            ...             ...
# 1492       -1.0               0.0        0          34.55             0.0
# 1493       -1.0               0.0        0          34.55             0.0
# 1494       -1.0               0.0        0          34.55             0.0
# 1495       -1.0               0.0        0          34.55             0.0
# 1496       -1.0               0.0        0          34.55             0.0
#
#       Average Reputation Score  International Score
# ...

# %% [markdown]
# #**CONSTRUCT DATA**

# %% [markdown]
# Pada bagian ini, akan Data akan di Construct dari (International Score, Overall Score, Ranking Change, dan 2024 RANK).

# %%
if 'International Score' in df.columns and 'Overall SCORE' in df.columns:
    df['International Score (%)'] = (df['International Score'] / df['Overall SCORE']) * 100

if 'Ranking Change' in df.columns and '2024 RANK' in df.columns:
    df['Ranking Change (%)'] = (df['Ranking Change'] / df['2024 RANK']) * 100

print(df.head())
# Out:
#    2024 RANK  Institution Name  Country  Overall SCORE  Ranking Change  \
# 0        1.0               0.0        0           65.5             0.0
# 1        2.0               0.0        0           65.5             0.0
# 2        3.0               0.0        0           65.5             1.0
# 3        4.0               0.0        0           65.5             1.0
# 4        5.0               0.0        0           65.5            -2.0
#
#    Average Reputation Score  International Score  International Score (%)  \
# 0                      77.7                94.10               143.664122
# 1                      77.7                97.90               149.465649
# 2                      77.7                97.45               148.778626
# 3                      77.7                75.70               115.572519
# 4                      77.7                75.55               115.343511
#
#    Ranking Change (%)
# 0            0.000000
# 1            0.000000
# 2           33.333333
# ...

# %% [markdown]
# #**CHECKPOINT 3 AVD**

# %% [markdown]
# # **Matplotlib & Seaborn**

# %% [markdown]
# - Distribusi Perubahan Peringkat Universitas.
# - Skor International Vs Peringkat Universitas

# %%
plt.figure(figsize=(8, 5))
if 'Ranking Change (%)' in df.columns:
  ranking_change_grouped = df.groupby('Ranking Change (%)').size()
  ranking_change_grouped.plot(kind='bar', color='blue', edgecolor='black')
  plt.title('Distribusi Perubahan Peringkat Universitas')
  plt.xlabel('Perubahan Peringkat (%)')
  plt.ylabel('Jumlah Universitas')
  plt.xticks(rotation=0)
  plt.show()

# %%
if 'International Score (%)' in df.columns and '2024 RANK' in df.columns:
    grouped_df = df.groupby('International Score (%)')['2024 RANK'].mean().reset_index()

    plt.figure(figsize=(8, 5))
    ranking_change_grouped.plot(kind='bar', color='blue', edgecolor='black')
    plt.title('Skor Internasional vs Peringkat Universitas')
    plt.xlabel('Skor Internasional (%)')
    plt.ylabel('Peringkat Universitas')
    plt.gca().invert_yaxis()
    plt.show()

# %%
if 'Ranking Change (%)' in df.columns:
    df['Ranking Change (%)'].hist(bins=20, edgecolor='blue')
    plt.title('Distribusi Perubahan Peringkat Universitas')
    plt.xlabel('Perubahan Peringkat (%)')
    plt.ylabel('Jumlah Universitas')
    plt.show()

# %%
if 'International Score (%)' in df.columns and '2024 RANK' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=df['International Score (%)'], y=df['2024 RANK'])
    plt.title('Skor Internasional vs Peringkat Universitas')
    plt.xlabel('Skor Internasional (%)')
    plt.ylabel('Peringkat Universitas')
    plt.gca().invert_yaxis()
    plt.show()
